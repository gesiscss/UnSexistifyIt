# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import json

with open('../json_files/cdf_data.json') as json_file:
    data = json.load(json_file)

# %%
levenshtein = []
for value in data.values():
    for item in value:
        levenshtein.append(item['levenshtein'])

fig, ax = plt.subplots(figsize=(12, 8))

x = np.sort(levenshtein)
y = np.arange(len(x))/float(len(x))

# plot(x, y, linestyle='dashed')

# Plot both
plt.style.use('fivethirtyeight')
plt.plot(x, y , color='black', lw=5, alpha=0.8)
ax.grid(True)
ax.set_title('Levenshtein distance x Sentences CDF', fontsize=24)
ax.set_xlabel('Value', fontsize=20)
ax.set_ylabel('Sentences (%)', fontsize=20)
plt.savefig('../images/levenshtein.png')
plt.show()

# %%
lenght_diff = []
for value in data.values():
    for item in value:
        lenght_diff.append(item['lenght_diff'])
        
fig, ax = plt.subplots(figsize=(12, 8))

x = np.sort(lenght_diff)
y = np.arange(len(x))/float(len(x))

# plt.style.use('fivethirtyeight')
plt.plot(x,y , color='black', lw=5, alpha=0.8)

ax.grid(True)
ax.set_xlabel('Difference Length', fontsize=20)
ax.set_ylabel('Sentences (%)', fontsize=20)
plt.savefig('../images/lenght_diff.png')
plt.show()

# %%
changed_gender = []
for value in data.values():
    for item in value:
        changed_gender.append(item['changedGender'])
        
fig, ax = plt.subplots(figsize=(12, 8))

x = np.sort(changed_gender)
y = np.arange(len(x))/float(len(x))

# Plot both
plt.style.use('fivethirtyeight')
plt.plot(x, y , color='black', lw=5, alpha=0.8)
ax.grid(True)
ax.set_title('Changed Gender words x Sentences CDF', fontsize=24)
ax.set_xlabel('Value', fontsize=20)
ax.set_ylabel('Sentences (%)', fontsize=20)
plt.savefig('../images/changed_gender.png')
plt.show()

# %%
changed_not = []
for value in data.values():
    for item in value:
        changed_not.append(item['changedNot'])
        
fig, ax = plt.subplots(figsize=(12, 8))

x = np.sort(changed_not)
y = np.arange(len(x))/float(len(x))

# Plot both
plt.style.use('fivethirtyeight')
plt.plot(x, y , color='black', lw=5, alpha=0.8)
ax.grid(True)
ax.set_title('Changed Negative words x Sentences CDF', fontsize=24)
ax.set_xlabel('Value', fontsize=20)
ax.set_ylabel('Sentences (%)', fontsize=20)
plt.savefig('../images/changed_not.png')
plt.show()
